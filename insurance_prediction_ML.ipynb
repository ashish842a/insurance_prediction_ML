# %% [markdown]
# # Program for predicting person having insurance acc to age group or buying a insurance acc to age group

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Read the Insurance dataset

# %%
df = pd.read_csv("insurance_data.csv")
df.head(5)
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %% [markdown]
# # Analysis of data using scatter plot

# %%
# Plotting
plt.xlabel("age")
plt.ylabel("bought_insurance")
plt.scatter(df['age'], df['bought_insurance'], marker="+")

# Fit logistic regression model
log_reg = LogisticRegression()
log_reg.fit(df[['age']], df['bought_insurance'])

# Plot logistic regression line
x_values = df['age'].values.reshape(-1, 1)
y_values = log_reg.predict_proba(x_values)[:, 1]
plt.plot(x_values, y_values, color='red')

plt.show()
# Out:
# D:\softwares or programs\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
# df.info()b
# df.isnull().sum()
# df.duplicated()
# df.describe()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(df[['age']],df['bought_insurance'],test_size=0.1)

# %% [markdown]
# # X_train
# X_test

# %% [markdown]
# # Train the model using Logistic Regressin

# %%
# Create a logistic regression model
model = LogisticRegression()

# Fit the model to your data
model.fit(X_train, Y_train)
model
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 0, 0], dtype=int64)

# %%
model.score(X_test,Y_test)
# Out:
# 1.0

# %% [markdown]
# # Export Model using joblib

# %%
import joblib

# %%
joblib.dump(model,"insurance_train_model")
# Out:
# ['insurance_train_model']

# %% [markdown]
# # Import Model using joblib

# %%
ml = joblib.load('insurance_train_model')

# %%
# ml.predict([[53]])
ml.predict(X_test)
# Out:
# array([0, 0, 0], dtype=int64)

# %% [markdown]
# # Export Model using pickle

# %%
import pickle

# %%
with open("model_pickle_insurance","wb") as f:
    pickle.dump(model,f)

# %% [markdown]
# # Import model using pickle

# %%
with open("model_pickle_insurance","rb") as f:
    mb = pickle.load(f)

# %%
# mb.predict([[23]])
mb.predict(X_test)
# Out:
# array([0, 0, 0], dtype=int64)
